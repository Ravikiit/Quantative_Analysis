# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravikiit/Quantative_Analysis/blob/main/PART7_3_Monte_Carlo_Predicting_Gross_Profit_Part_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np  
import pandas as pd  
from pandas_datareader import data as wb  
import matplotlib.pyplot as plt  
from scipy.stats import norm
# %matplotlib inline

# %%
data = pd.read_csv('PG_2007_2017.csv', index_col = 'Date')

# %%
log_returns = np.log(1 + data.pct_change())

# %%
log_returns.tail()
# Out:
#                   PG
# Date
# 2017-04-04  0.002562
# 2017-04-05  0.000667
# 2017-04-06 -0.006356
# 2017-04-07 -0.001903
# 2017-04-10  0.002910

# %%
data.plot(figsize=(10, 6));

# %%
log_returns.plot(figsize = (10, 6))

# %%
u = log_returns.mean()
u
# Out:
# PG    0.000244
# dtype: float64

# %%
var = log_returns.var()
var
# Out:
# PG    0.000124
# dtype: float64

# %%
drift = u - (0.5 * var)
drift
# Out:
# PG    0.000182
# dtype: float64

# %%
stdev = log_returns.std()
stdev
# Out:
# PG    0.011138
# dtype: float64
